# %% [markdown]
# ### Creating a simulation for baseball games, based on 538's riddler:
# https://fivethirtyeight.com/features/can-you-turn-americas-pastime-into-a-game-of-yahtzee/

# %%
import random 
import numpy as np
import pandas as pd

# %% [markdown]
# #### First, I made a dice roller.  It outputs a list of 2 integers, from 1-6.  I had it print out the baseball action, which will be helpful for logging and debugging later on.

# %%
def roll_2_die(verbose=True):
    d = [random.randint(1,6), random.randint(1,6)]
    d = sorted(d)
    if verbose:
        if d in [[1,1]]:
            print 'rolled a double'
        elif d in [[1,2], [1,3], [1,4]]:
            print 'rolled a single'
        elif d in [[1,5]]:
            print 'rolled a base on error'    
        elif d in [[1,6]]:
            print 'rolled a base on balls'
        elif d in [[2,2,], [2,3], [2,4], [2,5]]:
            print 'rolled a strike'
        elif d in [[2,6]]:
            print 'rolled a foul out'
        elif d in [[3,3], [3,4], [3,5], [3,6]]:
            print 'rolled a out at 1st'
        elif d in [[4,4], [4,5], [4,6]]:
            print 'rolled a fly out'
        elif d in [[5,5]]:
            print 'rolled a double play'
        elif d in [[5,6]]:
            print 'rolled a triple'
        elif d in [[6,6]]:
            print 'rolled a home run'
        else:
            print 'error:', d
    
    return(d)

print'example output :', roll_2_die()
# Out:
# example output : rolled a strike
# [2, 5]

# %% [markdown]
# #### I'm putting the running game stats in a dictionary: innings, outs, strikes etc.  I created an intialize game function for use in the multi-game simulation, so I could reset the game quickly.

# %%
def initialize_game():
    game = {'_score': 0,
            '__inning': 1,
            '__outs': 0, 
            '__strikes':0, 
            'runner_on_1': False,
            'runner_on_2': False,
            'runner_on_3': False,
            }
    return(game)

game = initialize_game()
print 'the running game stats will look like this:',game
# Out:
# the running game stats will look like this: {'__inning': 1, '__strikes': 0, '_score': 0, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}

# %% [markdown]
# #### Now I made a function that simulates 1 dice roll.  The game dictionary and the die values are inputs, and the function applies the appropriate increments to the stats of the game dictionary.   The riddle leaves some open questions about how to handle base runners.  For instance, it assumes that runners can score from 2nd on a single.  Fly out, foul out, and out on 1st are much less clear, so I've made some debatable assumptions as to when runners will and won't advance.

# %%
def roll_once(d, game):
    # 1,1 double
    if d in [[1,1]]:
        # runner on 3rd scores
        if game['runner_on_3']:
            game['_score'] += 1
            game['runner_on_3'] = False
        # runner on 2nd scores
        if game['runner_on_2']:
            game['_score'] += 1
            game['runner_on_2'] = False
        # runner on 1st advances to 3rd
        if game['runner_on_1']:
            game['runner_on_3'] = True
        # hitter is now on 2nd
        game['runner_on_2'] = True
         # reset strikes
        game['__strikes'] = 0       
    # singles
    elif d in [[1,2], [1,3], [1,4]]:
        # runner on 3rd scores
        if game['runner_on_3']:
            game['_score'] += 1
            game['runner_on_3'] = False
        # runner on 2nd scores
        if game['runner_on_2']:
            game['_score'] += 1
            game['runner_on_2'] = False
        # runner on 1st advances
        if game['runner_on_1']:
            game['runner_on_2'] = True
        # hitter is on 1st
        game['runner_on_1'] = True
        # reset strikes
        game['__strikes'] = 0
    # base on error
    elif d in [[1,5]]:
        # runner on 3rd scores
        if game['runner_on_3']:
            game['_score'] += 1
            game['runner_on_3'] = False
        # runner on 2nd advances to 3rd
        if game['runner_on_2']:
            game['runner_on_2'] = False
            game['runner_on_3'] = True
        # runner on 1st advances
        if game['runner_on_1']:
            game['runner_on_2'] = True
        # hitter is on 1st
        game['runner_on_1'] = True
        # reset strikes
        game['__strikes'] = 0       
    # base on balls
    elif d in [[1,6]]:
        # walked, with runner on first will advance some runners
        if game['runner_on_1']:
            # walked, with bases loaded just increments score, bases still loaded
            if game['runner_on_3'] and game['runner_on_2']:
                game['_score'] += 1
            # walked with 1st and 2nd, now loaded
            elif game['runner_on_2']:
                game['runner_on_3'] = True
            # walked with runner on 1st, now 1st and 2nd
            else:
                game['runner_on_2'] = True
        # walked, without runner on first will just put hitter on first
        else:
            game['runner_on_1'] = True   
        # reset strikes
        game['__strikes'] = 0 
    # strikes
    elif d in [[2,2,], [2,3], [2,4], [2,5]]:
        game['__strikes'] = game['__strikes'] + 1
        # if strikes = 3, add an out and reset
        if game['__strikes'] == 3:
            game['__outs'] += 1
            game['__strikes'] = 0
    # foul out - advancing bases 30 % of the time
    elif d in [[2,6]]:
        # tag up occasionally advancing runners if under 2 outs
        if random.randint(1,10) <= 3 and game['__outs'] < 2:
             # runner on 3rd scores
            if game['runner_on_3']:
                game['_score'] += 1
                game['runner_on_3'] = False
            # runner on 2nd advances
            if game['runner_on_2']:
                game['runner_on_2'] = False
                game['runner_on_3'] = True
            # runner on 1st advances
            if game['runner_on_1']:
                game['runner_on_2'] = True   
        # increment the outs
        game['__outs'] += 1
        game['__strikes'] = 0
    # out at 1st
    elif d in [[3,3], [3,4], [3,5], [3,6]]:
        # The most debated logic..., runners advance 80% of the time
        # However, third base only advances 20% of the time if bases weren't loaded
        if (game['runner_on_3'] # on third
              and not(game['runner_on_2'] and game['runner_on_1']) # but not bases loaded
              and game['__outs'] < 2):
            if random.randint(1,10) <= 2:
                game['_score'] += 1
                game['runner_on_3'] = False                
                # runner on 2nd advances
                if game['runner_on_2']:
                    game['runner_on_2'] = False
                    game['runner_on_3'] = True 
                # runner on 1st advances
                if game['runner_on_1']:
                    game['runner_on_2'] = True
        elif game['__outs'] < 2 and random.randint(1,10) <= 8: # advance all runners 80% of the time 
            # runner on 3rd scores
            if game['runner_on_3']:
                game['_score'] += 1
                game['runner_on_3'] = False
            # runner on 2nd advances
            if game['runner_on_2']:
                game['runner_on_2'] = False
                game['runner_on_3'] = True
            # runner on 1st advances
            if game['runner_on_1']:
                game['runner_on_2'] = True              
        # increment the outs
        game['__outs'] += 1
        game['__strikes'] = 0
    # fly out -- advancing bases 60 % of the time
    elif d in [[4,4], [4,5], [4,6]]:
        # tag up occasionally advancing runners if under 2 outs
        if random.randint(1,10) <= 6 and game['__outs'] < 2:
             # runner on 3rd scores
            if game['runner_on_3']:
                game['_score'] += 1
                game['runner_on_3'] = False
            # runner on 2nd advances
            if game['runner_on_2']:
                game['runner_on_2'] = False
                game['runner_on_3'] = True
            # runner on 1st advances
            if game['runner_on_1']:
                game['runner_on_2'] = True   
        # increment the outs
        game['__outs'] += 1
        game['__strikes'] = 0
    # double play
    elif d in [[5,5]]:
        # increment the outs
        game['__outs'] += 2
        game['__strikes'] = 0
    # triple
    elif d in [[5,6]]:
        # runner on 3rd scores
        if game['runner_on_3']:
            game['_score'] += 1
            game['runner_on_3'] = False
        # runner on 2nd scores
        if game['runner_on_2']:
            game['_score'] += 1
            game['runner_on_2'] = False
        # runner on 1st scores
        if game['runner_on_1']:
            game['_score'] += 1
            game['runner_on_1'] = False
        # hitter is now on 3rd
        game['runner_on_3'] = True
         # reset strikes
        game['__strikes'] = 0  
    # home run
    elif d in [[6,6]]:
        # runner on 3rd scores
        if game['runner_on_3']:
            game['_score'] += 1
            game['runner_on_3'] = False
        # runner on 2nd scores
        if game['runner_on_2']:
            game['_score'] += 1
            game['runner_on_2'] = False
        # runner on 1st scores
        if game['runner_on_1']:
            game['_score'] += 1
            game['runner_on_1'] = False
        # hitter scores
        game['_score'] += 1
         # reset strikes
        game['__strikes'] = 0  
    else:
        print 'error:', d
    
    # settle the outs/innings
    if game['__outs'] > 2:
        game['__inning'] += 1
        game['__outs'] = 0
        game['__strikes'] = 0
        game['runner_on_1'] = False
        game['runner_on_2'] = False
        game['runner_on_3'] = False
    return(game)

# %% [markdown]
# #### Now that I can simulate one roll, this function will simulate a full 9 innings.

# %%
def play_1_game(verbose=False):
    game = initialize_game()
    count = 0
    while game['__inning'] <= 9:
        count += 1
        d = roll_2_die(verbose=verbose)
        game = roll_once(d, game)
        if verbose:
            print 'game stats after roll {}:'.format(count), game
    return(game)  

play_1_game(verbose=True)
# Out:
# rolled a single
# game stats after roll 1: {'__inning': 1, '__strikes': 0, '_score': 0, '__outs': 0, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a out at 1st
# game stats after roll 2: {'__inning': 1, '__strikes': 0, '_score': 0, '__outs': 1, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a fly out
# game stats after roll 3: {'__inning': 1, '__strikes': 0, '_score': 0, '__outs': 2, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a strike
# game stats after roll 4: {'__inning': 1, '__strikes': 1, '_score': 0, '__outs': 2, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a double play
# game stats after roll 5: {'__inning': 2, '__strikes': 0, '_score': 0, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a base on error
# game stats after roll 6: {'__inning': 2, '__strikes': 0, '_score': 0, '__outs': 0, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a base on error
# game stats after roll 7: {'__inning': 2, '__strikes': 0, '_score': 0, '__outs': 0, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a out at 1st
# game stats after roll 8: {'__inning': 2, '__strikes': 0, '_score': 0, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a strike
# game stats after roll 9: {'__inning': 2, '__strikes': 1, '_score': 0, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a base on balls
# game stats after roll 10: {'__inning': 2, '__strikes': 0, '_score': 1, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a single
# game stats after roll 11: {'__inning': 2, '__strikes': 0, '_score': 3, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a strike
# game stats after roll 12: {'__inning': 2, '__strikes': 1, '_score': 3, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a strike
# game stats after roll 13: {'__inning': 2, '__strikes': 2, '_score': 3, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a strike
# game stats after roll 14: {'__inning': 2, '__strikes': 0, '_score': 3, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a base on balls
# game stats after roll 15: {'__inning': 2, '__strikes': 0, '_score': 3, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a fly out
# game stats after roll 16: {'__inning': 3, '__strikes': 0, '_score': 3, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a home run
# game stats after roll 17: {'__inning': 3, '__strikes': 0, '_score': 4, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a single
# game stats after roll 18: {'__inning': 3, '__strikes': 0, '_score': 4, '__outs': 0, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a fly out
# game stats after roll 19: {'__inning': 3, '__strikes': 0, '_score': 4, '__outs': 1, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a base on error
# game stats after roll 20: {'__inning': 3, '__strikes': 0, '_score': 4, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a fly out
# game stats after roll 21: {'__inning': 3, '__strikes': 0, '_score': 4, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a triple
# game stats after roll 22: {'__inning': 3, '__strikes': 0, '_score': 6, '__outs': 2, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': True}
# rolled a base on error
# game stats after roll 23: {'__inning': 3, '__strikes': 0, '_score': 7, '__outs': 2, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a base on balls
# game stats after roll 24: {'__inning': 3, '__strikes': 0, '_score': 7, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a out at 1st
# game stats after roll 25: {'__inning': 4, '__strikes': 0, '_score': 7, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a strike
# game stats after roll 26: {'__inning': 4, '__strikes': 1, '_score': 7, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a strike
# game stats after roll 27: {'__inning': 4, '__strikes': 2, '_score': 7, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a single
# game stats after roll 28: {'__inning': 4, '__strikes': 0, '_score': 7, '__outs': 0, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a fly out
# game stats after roll 29: {'__inning': 4, '__strikes': 0, '_score': 7, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a double
# game stats after roll 30: {'__inning': 4, '__strikes': 0, '_score': 8, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a single
# game stats after roll 31: {'__inning': 4, '__strikes': 0, '_score': 10, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a fly out
# game stats after roll 32: {'__inning': 4, '__strikes': 0, '_score': 10, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a single
# game stats after roll 33: {'__inning': 4, '__strikes': 0, '_score': 11, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a out at 1st
# game stats after roll 34: {'__inning': 5, '__strikes': 0, '_score': 11, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a out at 1st
# game stats after roll 35: {'__inning': 5, '__strikes': 0, '_score': 11, '__outs': 1, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a strike
# game stats after roll 36: {'__inning': 5, '__strikes': 1, '_score': 11, '__outs': 1, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a strike
# game stats after roll 37: {'__inning': 5, '__strikes': 2, '_score': 11, '__outs': 1, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a single
# game stats after roll 38: {'__inning': 5, '__strikes': 0, '_score': 11, '__outs': 1, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a strike
# game stats after roll 39: {'__inning': 5, '__strikes': 1, '_score': 11, '__outs': 1, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a out at 1st
# game stats after roll 40: {'__inning': 5, '__strikes': 0, '_score': 11, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a out at 1st
# game stats after roll 41: {'__inning': 6, '__strikes': 0, '_score': 11, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a base on balls
# game stats after roll 42: {'__inning': 6, '__strikes': 0, '_score': 11, '__outs': 0, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a base on balls
# game stats after roll 43: {'__inning': 6, '__strikes': 0, '_score': 11, '__outs': 0, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a foul out
# game stats after roll 44: {'__inning': 6, '__strikes': 0, '_score': 11, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a fly out
# game stats after roll 45: {'__inning': 6, '__strikes': 0, '_score': 11, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a single
# game stats after roll 46: {'__inning': 6, '__strikes': 0, '_score': 13, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a foul out
# game stats after roll 47: {'__inning': 7, '__strikes': 0, '_score': 13, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a foul out
# game stats after roll 48: {'__inning': 7, '__strikes': 0, '_score': 13, '__outs': 1, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a double play
# game stats after roll 49: {'__inning': 8, '__strikes': 0, '_score': 13, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a single
# game stats after roll 50: {'__inning': 8, '__strikes': 0, '_score': 13, '__outs': 0, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a home run
# game stats after roll 51: {'__inning': 8, '__strikes': 0, '_score': 15, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a single
# game stats after roll 52: {'__inning': 8, '__strikes': 0, '_score': 15, '__outs': 0, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a base on error
# game stats after roll 53: {'__inning': 8, '__strikes': 0, '_score': 15, '__outs': 0, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a strike
# game stats after roll 54: {'__inning': 8, '__strikes': 1, '_score': 15, '__outs': 0, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a base on balls
# game stats after roll 55: {'__inning': 8, '__strikes': 0, '_score': 15, '__outs': 0, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a single
# game stats after roll 56: {'__inning': 8, '__strikes': 0, '_score': 17, '__outs': 0, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a out at 1st
# game stats after roll 57: {'__inning': 8, '__strikes': 0, '_score': 17, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a single
# game stats after roll 58: {'__inning': 8, '__strikes': 0, '_score': 19, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a double
# game stats after roll 59: {'__inning': 8, '__strikes': 0, '_score': 20, '__outs': 1, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a out at 1st
# game stats after roll 60: {'__inning': 8, '__strikes': 0, '_score': 20, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a out at 1st
# game stats after roll 61: {'__inning': 9, '__strikes': 0, '_score': 20, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a out at 1st
# game stats after roll 62: {'__inning': 9, '__strikes': 0, '_score': 20, '__outs': 1, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# rolled a base on error
# game stats after roll 63: {'__inning': 9, '__strikes': 0, '_score': 20, '__outs': 1, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a foul out
# game stats after roll 64: {'__inning': 9, '__strikes': 0, '_score': 20, '__outs': 2, 'runner_on_1': True, 'runner_on_2': False, 'runner_on_3': False}
# rolled a base on error
# game stats after roll 65: {'__inning': 9, '__strikes': 0, '_score': 20, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a strike
# game stats after roll 66: {'__inning': 9, '__strikes': 1, '_score': 20, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': False}
# rolled a base on balls
# game stats after roll 67: {'__inning': 9, '__strikes': 0, '_score': 20, '__outs': 2, 'runner_on_1': True, 'runner_on_2': True, 'runner_on_3': True}
# rolled a triple
# game stats after roll 68: {'__inning': 9, '__strikes': 0, '_score': 23, '__outs': 2, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': True}
# rolled a fly out
# game stats after roll 69: {'__inning': 10, '__strikes': 0, '_score': 23, '__outs': 0, 'runner_on_1': False, 'runner_on_2': False, 'runner_on_3': False}
# {'__inning': 10,
#  '__outs': 0,
#  '__strikes': 0,
#  '_score': 23,
#  'runner_on_1': False,
#  'runner_on_2': False,
#  'runner_on_3': False}

# %% [markdown]
# #### That works, now simulate a bunch of games.  I logged the end score of each game to a list.  Then we can see what the average value is.

# %%
number_of_games = 1000000
scores = []
for g in range(0,number_of_games):
    game = play_1_game(verbose=False)
    scores.append(game['_score'])

print 'the average score for {} games is: {}'.format(number_of_games, float(sum(scores)) / len(scores))
# Out:
# the average score for 1000000 games is: 16.232338
